# %% [markdown]
# ### Carregando Dataset

# %%
import pandas as pd

work_directory = "../../combustiveis/"
dataset_name = "dataset_etanol_sp.csv"

df = pd.read_csv(work_directory + dataset_name, sep=",", decimal=".", encoding="cp860", index_col=False)

# %%
df = df.dropna()

# %%
df.head()
# Out:
#    Semestre ΓêÒΓòùΓõÉRegiao - Sigla Estado - Sigla  Municipio  \
# 6   2020-01                      SE             SP     AMPARO
# 14  2020-01                      SE             SP    ATIBAIA
# 15  2020-01                      SE             SP    ATIBAIA
# 30  2020-01                      SE             SP   CACAPAVA
# 62  2020-01                      SE             SP  GUARULHOS
#
#                                  Revenda      CNPJ da Revenda  \
# 6                    AUTO POSTO DBV LTDA   09.371.227/0001-18
# 14               POSTO 22 - ATIBAIA LTDA   05.343.449/0001-76
# 15  POSTO DE COMBUSTIVEL ATIBAIA SP LTDA   69.345.254/0001-48
# 30   CARREFOUR COMERCIO E INDUSTRIA LTDA   45.543.915/0355-62
# 62                  FAROL COMERCIAL LTDA   49.091.291/0001-60
#
#                  Nome da Rua Numero Rua           Complemento  \
# 6       AVENIDA ANESIO GUIDI        344  ESQ.R.RACHID KASSOUF
# 14       RODOVIA FERNAO DIAS        S/N              KM. 47,5
# 15       RODOVIA FERNAO DIAS        S/N                 KM 50
# 30            AVENIDA BRASIL        401               SETOR I
# 62  RODOVIA PRESIDENTE DUTRA        S/N        KM 208+620 MTS
#
#                   Bairro        Cep Produto Data da Coleta  Valor de Venda  \
# 6   DISTRITO TRES PONTES  13909-000  ETANOL     02/01/2020           3.099
# 14                PORTAO  12949-030  ETANOL     03/01/2020           2.997
# 15            PORTΓõ£├óO  12940-000  ETANOL     03/01/2020           3.097
# 30                CENTRO  12287-020  ETANOL     03/01/2020           3.079
# 62            BONSUCESSO  07178-580  ETANOL     03/01/2020           2.949
#
#     Valor de Compra Unidade de Medida                      Bandeira
# 6            2.6887        R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 14           2.7501        R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 15           2.7555        R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 30           2.6946        R$ / litro                        RAIZEN
# 62           2.6726        R$ / litro                        RAIZEN

# %%
df = df[["Valor de Venda", "Valor de Compra"]]

# %%
df
# Out:
#          Valor de Venda  Valor de Compra
# 6                 3.099           2.6887
# 14                2.997           2.7501
# 15                3.097           2.7555
# 30                3.079           2.6946
# 62                2.949           2.6726
# ...                 ...              ...
# 2031909           1.979           1.7599
# 2031918           2.199           1.9351
# 2031950           2.299           2.0434
# 2031981           2.199           1.9000
# 2031996           2.649           2.1832
#
# [149410 rows x 2 columns]

# %% [markdown]
# ### Visualizando Correlações

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import scatterplotmatrix
import seaborn as sns

# Scatter
scatterplotmatrix(df.values, figsize=(10, 8), names=df.columns, alpha=0.5)
plt.tight_layout()
plt.show()

# Pair Plot
sns.set(style='whitegrid', context='notebook')
cols = df.columns
sns.pairplot(df, height=2.5)
plt.show()

# Heat Map

sns.heatmap(df.corr(),annot=True,cmap='summer')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Realizando Regressão Linear

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Definindo valores que serão utilizados
X = df[["Valor de Compra"]].values
y = df["Valor de Venda"].values

# Separando dados de treino e de teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# Treinando o modelo
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

plt.figure(figsize = (15,8))
plt.scatter(df['Valor de Compra'], df['Valor de Venda'], c='steelblue', edgecolor='white', s=70)

plt.plot(X_test, y_pred, c='blue',linewidth=3, linestyle='solid')

plt.xlabel("Valor de Compra")
plt.ylabel("Valor de Venda")
plt.show()

# %% [markdown]
# ### Regressão Linear Conforme Modelo do Professor

# %%
X = df[["Valor de Compra"]].values
Y = df["Valor de Venda"].values

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

sc_x = StandardScaler()
sc_y = StandardScaler()
x_std = sc_x.fit_transform(X)
y_std = sc_y.fit_transform(Y[:,np.newaxis]).flatten()

# %%
lr = LinearRegression()
lr.fit(x_std, y_std)
# Out:
# LinearRegression()

# %%
def lin_regplot(X, y, model):
    plt.scatter(X, y, c='steelblue', edgecolor='white', s=70)
    plt.plot(X, model.predict(X), color='black', lw=2)
    return

# %%
lin_regplot(x_std, y_std, lr)
plt.xlabel('Valor de Compra')
plt.ylabel('Valor de Venda')
plt.show()
