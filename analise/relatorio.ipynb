# %%
import pandas as pd
from pandas_profiling import ProfileReport

# %%
df = pd.read_csv("../../combustiveis/ca-2020-01.csv", sep=";", decimal=",", encoding="cp860")

print("Dataset carregado. Quantidade de registros:" + str(len(df.index)))
# Out:
# Dataset carregado. Quantidade de registros:496663

# %%
profile = ProfileReport(df, title="Pandas Profiling Report")

profile.to_file("report.html")
# Out:
# Summarize dataset: 100%|██████████████████████████████████████████████████████████████████████████| 35/35 [00:24<00:00,  1.41it/s, Completed]
# Generate report structure: 100%|███████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.14s/it]
# Render HTML: 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# Export report to file: 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 210.77it/s]

# %%
# Remover valores não-numéricos
df = df.dropna()

# %%
df.columns
# Out:
# Index(['∩╗┐Regiao - Sigla', 'Estado - Sigla', 'Municipio', 'Revenda',
#        'CNPJ da Revenda', 'Nome da Rua', 'Numero Rua', 'Complemento', 'Bairro',
#        'Cep', 'Produto', 'Data da Coleta', 'Valor de Venda', 'Valor de Compra',
#        'Unidade de Medida', 'Bandeira'],
#       dtype='object')

# %%
df
# Out:
#        ∩╗┐Regiao - Sigla Estado - Sigla      Municipio  \
# 57                    NE             AL      ARAPIRACA
# 77                    NE             AL      ARAPIRACA
# 78                    NE             AL      ARAPIRACA
# 79                    NE             AL      ARAPIRACA
# 80                    NE             AL      ARAPIRACA
# ...                  ...            ...            ...
# 496511                NE             BA       SALVADOR
# 496530                CO             MT  ALTA FLORESTA
# 496531                CO             MT  ALTA FLORESTA
# 496532                CO             MT  ALTA FLORESTA
# 496533                CO             MT  ALTA FLORESTA
#
#                                               Revenda      CNPJ da Revenda  \
# 57                        AUTO POSTO M M GARROTE LTDA   08.738.994/0001-50
# 77                        RODO CENTER AUTO POSTO LTDA   40.921.967/0001-20
# 78                        RODO CENTER AUTO POSTO LTDA   40.921.967/0001-20
# 79                        RODO CENTER AUTO POSTO LTDA   40.921.967/0001-20
# 80                        RODO CENTER AUTO POSTO LTDA   40.921.967/0001-20
# ...                                               ...                  ...
# 496511  SOBRAL & FILHOS COMERCIO DE COMBUSTIVEIS LTDA   11.322.064/0008-00
# 496530                           ARAUJO & DUENHA LTDA   26.348.807/0001-03
# 496531                           ARAUJO & DUENHA LTDA   26.348.807/0001-03
# 496532                           ARAUJO & DUENHA LTDA   26.348.807/0001-03
# 496533                           ARAUJO & DUENHA LTDA   26.348.807/0001-03
#
#                                       Nome da Rua Numero Rua  \
# 57                                 RODOVIA AL-220       5848
# 77                                 RODOVIA AL 220         SN
# 78                                 RODOVIA AL 220         SN
# 79                                 RODOVIA AL 220         SN
# 80                                 RODOVIA AL 220         SN
# ...                                           ...        ...
# 496511                   AVENIDA ALIOMAR BALEEIRO       6880
# 496530  AVENIDA PERIMETRAL DEPUTADO ROGERIO SILVA        S/N
# 496531  AVENIDA PERIMETRAL DEPUTADO ROGERIO SILVA        S/N
# 496532  AVENIDA PERIMETRAL DEPUTADO ROGERIO SILVA        S/N
# 496533  AVENIDA PERIMETRAL DEPUTADO ROGERIO SILVA        S/N
#
#                                Complemento                Bairro        Cep  \
# 57                                KM    96           BOM SUCESSO  57309-035
# 77                                   KM 06      JARDIM ESPERANCA  57304-820
# 78                                   KM 06      JARDIM ESPERANCA  57304-820
# 79                                   KM 06      JARDIM ESPERANCA  57304-820
# 80                                   KM 06      JARDIM ESPERANCA  57304-820
# ...                                    ...                   ...        ...
# 496511                  EST V DO AEROPORTO         NOVA BRASILIA  41350-275
# 496530  LOTE  01 E 03             QUADRA01  JARDIM ALMEIDA PRADO  78580-000
# 496531  LOTE  01 E 03             QUADRA01  JARDIM ALMEIDA PRADO  78580-000
# 496532  LOTE  01 E 03             QUADRA01  JARDIM ALMEIDA PRADO  78580-000
# 496533  LOTE  01 E 03             QUADRA01  JARDIM ALMEIDA PRADO  78580-000
#
#            Produto Data da Coleta  Valor de Venda  Valor de Compra  \
# 57        GASOLINA     02/01/2020           4.650           4.1903
# 77        GASOLINA     02/01/2020           4.699           4.2199
# 78          ETANOL     02/01/2020           3.399           3.0175
# 79          DIESEL     02/01/2020           3.899           3.5674
# 80      DIESEL S10     02/01/2020           3.999           3.6536
# ...            ...            ...             ...              ...
# 496511  DIESEL S10     30/06/2020           3.275           2.9404
# 496530    GASOLINA     29/06/2020           4.200           3.6000
# 496531      ETANOL     29/06/2020           2.630           2.2909
# 496532      DIESEL     29/06/2020           3.370           3.0650
# 496533  DIESEL S10     29/06/2020           3.590           3.1905
#
#        Unidade de Medida                      Bandeira
# 57            R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 77            R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 78            R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 79            R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 80            R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# ...                  ...                           ...
# 496511        R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 496530        R$ / litro                          WATT
# 496531        R$ / litro                          WATT
# 496532        R$ / litro                          WATT
# 496533        R$ / litro                          WATT
#
# [33831 rows x 16 columns]
