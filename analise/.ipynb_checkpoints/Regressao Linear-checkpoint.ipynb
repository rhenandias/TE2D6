# %% [markdown]
# ### Carregando Dataset

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
from pandas_profiling import ProfileReport

# %%
work_directory = "../../combustiveis/"
dataset_name = "dataset_etanol_sp.csv"

df = pd.read_csv(work_directory + dataset_name, sep=",", decimal=".", encoding="cp860", index_col=False)

print("Dataset carregado. Quantidade de registros: " + str(len(df.index)))
# Out:
# Dataset carregado. Quantidade de registros: 2032002

# %%
# Remover valores não-numéricos
df = df.dropna()

# %%
df = df[["Valor de Venda", "Valor de Compra"]]

# %%
df
# Out:
#          Valor de Venda  Valor de Compra
# 6                 3.099           2.6887
# 14                2.997           2.7501
# 15                3.097           2.7555
# 30                3.079           2.6946
# 62                2.949           2.6726
# ...                 ...              ...
# 2031909           1.979           1.7599
# 2031918           2.199           1.9351
# 2031950           2.299           2.0434
# 2031981           2.199           1.9000
# 2031996           2.649           2.1832
#
# [149410 rows x 2 columns]

# %% [markdown]
# ### Visualizando Correlações

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import scatterplotmatrix

scatterplotmatrix(df.values, figsize=(10, 8), names=df.columns, alpha=0.5)
plt.tight_layout()
plt.show()

# %%
sns.set(style='whitegrid', context='notebook')
cols = df.columns
sns.pairplot(df, height=2.5)
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.heatmap(df.corr(),annot=True,cmap='summer')
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import (ensemble,model_selection,preprocessing,tree,)
from sklearn.metrics import (auc,confusion_matrix,roc_auc_score,roc_curve,)
from sklearn.model_selection import( train_test_split,StratifiedKFold,)
from yellowbrick.classifier import (ConfusionMatrix,ROCAUC,)
from yellowbrick.model_selection import (LearningCurve,)
import janitor as jn

X, y = jn.get_features_targets(df, target_columns='Valor de Compra')
X_treino, X_test, Y_treino, Y_test = model_selection.train_test_split(X, y,
test_size=0.3, random_state=42)

print(X_treino)
# Out:
# /usr/local/lib/python3.8/dist-packages/janitor/utils.py:290: FutureWarning: get_features_targets() has moved. Please use ml.get_features_targets().
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [139], in <cell line: 11>()
#       8 from yellowbrick.model_selection import (LearningCurve,)
#       9 import janitor as jn
# ---> 11 X, y = jn.get_features_targets(df)
#      12 X_treino, X_test, Y_treino, Y_test = model_selection.train_test_split(X, y,
#      13 test_size=0.3, random_state=42)
#      15 print(X_treino)
#
# File /usr/local/lib/python3.8/dist-packages/janitor/utils.py:291, in refactored_function.<locals>.decorator.<locals>.emit_warning(*args, **kwargs)
#     289 def emit_warning(*args, **kwargs):
#     290     warnings.warn(message, FutureWarning)
# --> 291     return func(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/janitor/__init__.py:20, in get_features_targets(*args, **kwargs)
#      15 @refactored_function(
#      16     "get_features_targets() has moved. Please use ml.get_features_targets()."
#      17 )
#      18 def get_features_targets(*args, **kwargs):
#      19     """Wrapper for get_features_targets."""
# ---> 20     return _get_features_targets(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/janitor/utils.py:258, in deprecated_alias.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     255 @functools.wraps(func)
#     256 def wrapper(*args, **kwargs):
#     257     rename_kwargs(func.__name__, kwargs, aliases)
# --> 258     return func(*args, **kwargs)
#
# TypeError: get_features_targets() missing 1 required positional argument: 'target_column_names'

# %%
X = df[["Valor de Compra"]].values
Y = df["Valor de Venda"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# Criando o modelo LinearRegression
regr = LinearRegressionGD()
# Realizar treinamento do modelo
regr.fit(X_train, y_train)
# Realizar predição com os dados separados para teste
y_pred = lr.predict(X_test)

plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

sc_x = StandardScaler()
sc_y = StandardScaler()
x_std = sc_x.fit_transform(X)
y_std = sc_y.fit_transform(Y[:,np.newaxis]).flatten()

# %%
lr = LinearRegressionGD()
lr.fit(x_std, y_std)

# %%
plt.plot(range(1, lr.n_iter+1), lr.cost_)
plt.ylabel('SSE')
plt.xlabel('Epoch')
plt.show()

# %%
def lin_regplot(X, y, model):
    plt.scatter(X, y, c='steelblue', edgecolor='white', s=70)
    plt.plot(X, model.predict(X), color='black', lw=2)
    
    return

# %%
lin_regplot(x_std, y_std, lr)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
from   sklearn.linear_model import LinearRegression

X = df[["Valor de Compra"]].values
Y = df["Valor de Venda"].values


reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
f_previsaoes = reg.predict(X)


plt.figure(figsize = (16,8))
plt.scatter(
    df['Valor de Compra'], 
    df['Valor de Venda'], 
    c='red')


plt.plot(
    df['Valor de Compra'],
    f_previsaoes,
    c='blue',
    linewidth=3,
    linestyle=':'
)

plt.xlabel(" ($) Gasto em propaganda de TV")
plt.ylabel(" ($) Vendas")
plt.show()
